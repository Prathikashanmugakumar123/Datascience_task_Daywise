# %%
import pandas as pd
data=pd.read_csv("results.csv")
data
# Out:
#      Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 0             0     65       10       59      3       71         37    245
# 1             1     94       56        4     67       91         50    362
# 2             2      7       85       76     99       60         25    352
# 3             3     88       46       59     94       52         38    377
# 4             4     39       81       37     38        6         54    255
# ..          ...    ...      ...      ...    ...      ...        ...    ...
# 995         995     55       89       68     58       13         13    296
# 996         996     42       62       25     87       51         68    335
# 997         997      9       83       70     14       11         78    265
# 998         998     23       82       31     42       84         52    314
# 999         999     75       78       68     33       79         91    424
#
#      Results  Div
# 0          0    3
# 1          1    1
# ...

# %%
m1=data.loc[0:5,"Science"]
m2=data.loc[0:5,"History"]

# %%
science=data[["Science"]]
science
# Out:
#      Science
# 0         59
# 1          4
# 2         76
# 3         59
# 4         37
# ..       ...
# 995       68
# 996       25
# 997       70
# 998       31
# 999       68
#
# [1000 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
i=StandardScaler()
dd=i.fit_transform(science)

# %%
History=data[["History"]]
tt=i.fit_transform(History)
b=tt.loc[0:15]

# %%
import matplotlib.pyplot as plt
plt.plot(m1,m2,color="red",marker="o")
plt.title("marks")
plt.xlabel("science")
plt.ylabel("History")
plt.show()

# %%
import numpy as np
plt.hist(m1,color="red",bins=10,edgecolor="black")
plt.title("marks")
plt.xlabel("science")
plt.ylabel("History")
plt.show()

# %%
plt.plot(m1,m2,color="red",marker="o")
plt.title("marks")
plt.xlabel("science")
plt.ylabel("History")
plt.show()

# %%
companies = ['Apple', 'Samsung', 'Xiaomi', 'Others']
market_share = np.array([30, 25, 20, 25])
plt.pie(market_share, labels=companies, autopct='%1.2f%%', startangle=90)
plt.title('Mobile Market Share')
plt.show()

# %%
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
times = ['Morning', 'Afternoon', 'Evening']

temps = np.array([
    [28, 36, 31],
    [27, 35, 30],
    [29, 37, 32],
    [28, 38, 33],
    [30, 39, 34],
    [31, 40, 35],
    [29, 37, 33]
])

# Create the heatmap
plt.imshow(temps, cmap='OrRd', aspect='auto')# for equql cell
plt.colorbar(label="Temperature (°C)")
plt.title("chennai heat rate")
# Out:
# Text(0.5, 1.0, 'chennai heat rate')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simulated monthly rainfall data (in cm)
chennai = [32, 45, 50, 60, 55, 70, 65, 80, 75, 68, 58, 50]
mumbai = [25, 40, 55, 90, 110, 120, 130, 125, 100, 70, 50, 35]
delhi = [10, 15, 25, 35, 50, 60, 65, 55, 40, 30, 20, 15]

# Create a box plot
plt.boxplot([chennai, mumbai, delhi], labels=['Chennai', 'Mumbai', 'Delhi'])
plt.show()

# %%
import re
text="this is my email abc@gmail.com and cde@gmail.com"
a=re.findall(r'\w{2,}+@\w{2,}\.\w{2,}',text)
a
# Out:
# ['abc@gmail.com', 'cde@gmail.com']

# %%
text=input("Enter your text")
a=re.findall(r'abc@',text)
if a:
 print("found")
else:
 print("not found")
a
# Out:
# Enter your text hello everyone abc@gmail.com
# found
# ['abc@']

# %%
txt="Many students define paragraphs in terms of length: a paragraph is a group of at least five sentences, a paragraph is half a page long, etc. In reality, though, the unity and coherence of ideas among sentences is what constitutes a paragraph ."
search=re.search(r'terms',txt)
print(search)
# Out:
# <re.Match object; span=(35, 40), match='terms'>

# %%
txt="my phone number is 3"
extract=re.search(r'\d',txt)
print(extract)
# Out:
# <re.Match object; span=(19, 20), match='3'>

# %%
txt="my USA amount is $250"
s=re.sub(r'USA'," ",txt)
s
# Out:
# 'my   amount is $250'

# %%
txt="abc@gmail.com  cde@gmailcom"
d=re.match(r'\w{2,}@\w{2,}\.\w{2,}',txt)
d
# Out:
# <re.Match object; span=(0, 13), match='abc@gmail.com'>
